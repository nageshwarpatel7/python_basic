# %% [markdown]
# Outline
# 1. Introduction to variables
# 2. Declaring and Assigning variables
# 3. Naming Conventions
# 4. Understaning Variable Types
# 5. Type Checking and Conversion
# 6. Dynamic Typing
# 7. Practical examples and Common Errors

# %%
a= 100

# %%
## Declaring and Assigning Variables

age = 32 
height = 6.1
name="Krish"
is_student = True

## printing the variables

print("age :", age)
print("height:",height)
print("name:",name)
# Out:
# age : 32
# height: 6.1
# name: Krish

# %%
## Naming Conventions
## Variable names should be descriptive
## They must always starts with latter or '_' and contains latters,numbers and underscores
## Variable names are case sensitive

## Valid Variable names 

first_name ="Krish"
last_name = "Naik"

# %%
## Invalid Variable names 
#2age = 32
#first-name="Krish"
#@name="Krish"
# Out:
#   Cell In[3], line 3
#     2age = 32
#     ^
# SyntaxError: invalid decimal literal

# %%
## Case Sensitivity
name = "Krish"
Name = "Naik"

# %%
## Understanding Variable types
## Python id dynamically typed means the type of a varible is determined at runtime
age = 32 #int
height = 6.1 #float
name = "Krish" #string
is_student = True #bool

print(type(age))
# Out:
# <class 'int'>

# %%
## Type checking and conversion

type(height)
# Out:
# float

# %%
age = 25
print(type(age))

## Type conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
## Dynamic Typing 
## Python allows  the type of a variable to change as the program executes

var=10 #int 
print(var, type(var))

var = "Hello"
print(var, type(var))

var= 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
age = int(input("What is the age type"))
print(age, type(age))
# Out:
# 23 <class 'int'>
